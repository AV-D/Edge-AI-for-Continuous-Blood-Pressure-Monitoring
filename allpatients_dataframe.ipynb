# %% [markdown]
# #### From the train folder check all the segments for each patient and also check if they have both ABP and Pleth signals and be a minumum of two minutes of duration.
#
# For example in train folder we have patient p10019003, p10020306 etc folders, which have a segments like 87033314.. In segment 87033314, we have 10 subsegment 87033314_0000 to 87033314_0009. In subsegment, we have ABP and Pleth signals. We need to read the data from the subsegment.

# %%
import os
import wfdb

def display_segment_info(record):
    print(f"--- Segment Header Information for {record.record_name} ---")
    print(f"Record name and segment number: {record.record_name}")
    print(f"Number of signals: {record.n_sig}")
    print(f"Total duration: {record.sig_len / record.fs} seconds")
    print(f"Sampling frequency: {record.fs} Hz")
    print(f"Counter frequency: {record.counter_freq} Hz")
    print(f"Number of samples per signal: {record.sig_len}")
    print(f"Start time of the recording: {record.base_time}")
    print(f"Start date of the recording: {record.base_date}")
    print(f"Meta data: {record.comments}")
    print("--------------------------------------------------\n")

def display_subsegment_info(record):
    print(f"--- Subsegment Signal Information for {record.record_name} ---")
    print(f"Number of signals: {record.n_sig}")
    for i in range(record.n_sig):
        print(f"Signal {i+1} name: {record.sig_name[i]}")
        print(f"Signal {i+1} duration: {record.sig_len / record.fs} seconds")
    print("--------------------------------------------------\n")

def process_patient_folder(patient_folder_path):
    subsegment_list = []
    subsegment_abp_pleth_list = []
    min_max_durations = {'ABP': {'min': float('inf'), 'max': 0}, 'Pleth': {'min': float('inf'), 'max': 0}}
    for segment_folder in os.listdir(patient_folder_path):
        if segment_folder.startswith('8'):
            segment_folder_path = os.path.join(patient_folder_path, segment_folder)
            header_file_path = os.path.join(segment_folder_path, segment_folder + '.hea')
            if os.path.exists(header_file_path):
                segment_record = wfdb.rdheader(header_file_path[:-4])
                display_segment_info(segment_record)
                # Process subsegment header files
                subsegment_files = [f for f in os.listdir(segment_folder_path) if f.startswith(segment_folder + '_') and f.endswith('.hea')]
                for subsegment_file in subsegment_files:
                    subsegment_file_path = os.path.join(segment_folder_path, subsegment_file)
                    if os.path.exists(subsegment_file_path):
                        subsegment_record = wfdb.rdheader(subsegment_file_path[:-4])
                        display_subsegment_info(subsegment_record)
                        subsegment_list.append(subsegment_file_path[:-4]+'.dat')
                        # Check if both ABP and pleth signals are present and duration is at least 2 minutes
                        if subsegment_record.sig_name and 'ABP' in subsegment_record.sig_name and 'Pleth' in subsegment_record.sig_name:
                            abp_duration = subsegment_record.sig_len / subsegment_record.fs
                            pleth_duration = subsegment_record.sig_len / subsegment_record.fs
                            if abp_duration >= 120 and pleth_duration >= 120:
                                subsegment_abp_pleth_list.append(subsegment_file_path[:-4]+'.dat')
                                abp_index = subsegment_record.sig_name.index('ABP')
                                pleth_index = subsegment_record.sig_name.index('Pleth')
                                if subsegment_file_path[:-4]+'.dat' in subsegment_abp_pleth_list:
                                    min_max_durations['ABP']['min'] = min(min_max_durations['ABP']['min'], abp_duration)
                                    min_max_durations['ABP']['max'] = max(min_max_durations['ABP']['max'], abp_duration)
                                    min_max_durations['Pleth']['min'] = min(min_max_durations['Pleth']['min'], pleth_duration)
                                    min_max_durations['Pleth']['max'] = max(min_max_durations['Pleth']['max'], pleth_duration)
            else:
                print(f"Header file not found: {header_file_path}")
    print(f"Total number of subsegments: {len(subsegment_list)}")
    print(f"Total number of subsegments with ABP and Pleth: {len(subsegment_abp_pleth_list)}")
    print(f"Minimum and Maximum durations for ABP: {min_max_durations['ABP']['min']} seconds, {min_max_durations['ABP']['max']} seconds")
    print(f"Minimum and Maximum durations for Pleth: {min_max_durations['Pleth']['min']} seconds, {min_max_durations['Pleth']['max']} seconds")
    return subsegment_list, subsegment_abp_pleth_list

def process_all_patients(train_folder_path):
    all_subsegments = []
    all_subsegments_abp_pleth = []
    patients_with_abp_pleth = 0
    for patient_folder in os.listdir(train_folder_path):
        patient_folder_path = os.path.join(train_folder_path, patient_folder)
        if os.path.isdir(patient_folder_path):
            subsegments, subsegments_abp_pleth = process_patient_folder(patient_folder_path)
            all_subsegments.extend(subsegments)
            all_subsegments_abp_pleth.extend(subsegments_abp_pleth)
            if subsegments_abp_pleth:
                patients_with_abp_pleth += 1
    print(f"Number of patients with subsegments having both ABP and Pleth: {patients_with_abp_pleth}")
    print(f"Total number of patients that satisfied the condition: {patients_with_abp_pleth}")
    return all_subsegments, all_subsegments_abp_pleth

# Example usage
train_folder_path = r"E:\Research\Project Tiny\physionet.org\files\mimic4wdb\0.1.0\waves\train"
all_subsegments, all_subsegments_abp_pleth = process_all_patients(train_folder_path)
print()
# print("All subsegments:", all_subsegments)
print()
# print("Subsegments with ABP and pleth:", all_subsegments_abp_pleth)
# Out:
# --- Segment Header Information for 87033314 ---
# Record name and segment number: 87033314
# Number of signals: 6
# Total duration: 244454.4399535796 seconds
# Sampling frequency: 62.4725 Hz
# Counter frequency: 999.56 Hz
# Number of samples per signal: 15271680
# Start time of the recording: 19:05:46.807000
# Start date of the recording: 2155-07-10
# Meta data: ['wfdb 10.7', 'subject_id 10019003', 'hadm_id 21457723']
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0000 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 0.0 seconds
# Signal 2 name: III
# Signal 2 duration: 0.0 seconds
# Signal 3 name: V
# Signal 3 duration: 0.0 seconds
# Signal 4 name: aVR
# Signal 4 duration: 0.0 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 0.0 seconds
# Signal 6 name: Resp
# Signal 6 duration: 0.0 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0001 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 312.4574812917684 seconds
# Signal 2 name: V
# Signal 2 duration: 312.4574812917684 seconds
# Signal 3 name: aVR
# Signal 3 duration: 312.4574812917684 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 312.4574812917684 seconds
# Signal 5 name: Resp
# Signal 5 duration: 312.4574812917684 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0002 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: Resp
# Signal 3 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0003 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 1.5366761375005002 seconds
# Signal 2 name: V
# Signal 2 duration: 1.5366761375005002 seconds
# Signal 3 name: aVR
# Signal 3 duration: 1.5366761375005002 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 1.5366761375005002 seconds
# Signal 5 name: Resp
# Signal 5 duration: 1.5366761375005002 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0004 ---
# Number of signals: 4
# Signal 1 name: V
# Signal 1 duration: 3.585577654167834 seconds
# Signal 2 name: aVR
# Signal 2 duration: 3.585577654167834 seconds
# Signal 3 name: Pleth
# Signal 3 duration: 3.585577654167834 seconds
# Signal 4 name: Resp
# Signal 4 duration: 3.585577654167834 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0005 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 20581.215734923368 seconds
# Signal 2 name: V
# Signal 2 duration: 20581.215734923368 seconds
# Signal 3 name: aVR
# Signal 3 duration: 20581.215734923368 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 20581.215734923368 seconds
# Signal 5 name: Resp
# Signal 5 duration: 20581.215734923368 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0006 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 266.3571971667534 seconds
# Signal 2 name: V
# Signal 2 duration: 266.3571971667534 seconds
# Signal 3 name: II
# Signal 3 duration: 266.3571971667534 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 266.3571971667534 seconds
# Signal 5 name: Resp
# Signal 5 duration: 266.3571971667534 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0007 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 215723.7184361119 seconds
# Signal 2 name: V
# Signal 2 duration: 215723.7184361119 seconds
# Signal 3 name: aVR
# Signal 3 duration: 215723.7184361119 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 215723.7184361119 seconds
# Signal 5 name: Resp
# Signal 5 duration: 215723.7184361119 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0008 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 7160.910800752332 seconds
# Signal 2 name: V
# Signal 2 duration: 7160.910800752332 seconds
# Signal 3 name: aVR
# Signal 3 duration: 7160.910800752332 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 7160.910800752332 seconds
# Signal 5 name: Resp
# Signal 5 duration: 7160.910800752332 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 87033314_0009 ---
# Number of signals: 1
# Signal 1 name: Pleth
# Signal 1 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# Total number of subsegments: 10
# Total number of subsegments with ABP and Pleth: 0
# Minimum and Maximum durations for ABP: inf seconds, 0 seconds
# Minimum and Maximum durations for Pleth: inf seconds, 0 seconds
# --- Segment Header Information for 83404654 ---
# Record name and segment number: 83404654
# Number of signals: 7
# Total duration: 274696.22633958946 seconds
# Sampling frequency: 62.4725 Hz
# Counter frequency: 999.56 Hz
# Number of samples per signal: 17160960
# Start time of the recording: 17:02:28.554000
# Start date of the recording: 2135-01-21
# Meta data: ['wfdb 10.7', 'subject_id 10020306', 'hadm_id 23052851']
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0000 ---
# Number of signals: 7
# Signal 1 name: II
# Signal 1 duration: 0.0 seconds
# Signal 2 name: III
# Signal 2 duration: 0.0 seconds
# Signal 3 name: V
# Signal 3 duration: 0.0 seconds
# Signal 4 name: aVR
# Signal 4 duration: 0.0 seconds
# Signal 5 name: ABP
# Signal 5 duration: 0.0 seconds
# Signal 6 name: Pleth
# Signal 6 duration: 0.0 seconds
# Signal 7 name: Resp
# Signal 7 duration: 0.0 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0001 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 4271.959662251391 seconds
# Signal 2 name: V
# Signal 2 duration: 4271.959662251391 seconds
# Signal 3 name: aVR
# Signal 3 duration: 4271.959662251391 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 4271.959662251391 seconds
# Signal 5 name: Resp
# Signal 5 duration: 4271.959662251391 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0002 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: aVR
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: Resp
# Signal 5 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0003 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 15.366761375005003 seconds
# Signal 2 name: V
# Signal 2 duration: 15.366761375005003 seconds
# Signal 3 name: II
# Signal 3 duration: 15.366761375005003 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 15.366761375005003 seconds
# Signal 5 name: Resp
# Signal 5 duration: 15.366761375005003 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0004 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 5931.569890751931 seconds
# Signal 2 name: V
# Signal 2 duration: 5931.569890751931 seconds
# Signal 3 name: aVR
# Signal 3 duration: 5931.569890751931 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 5931.569890751931 seconds
# Signal 5 name: Resp
# Signal 5 duration: 5931.569890751931 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0005 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 3145.0638280843573 seconds
# Signal 2 name: V
# Signal 2 duration: 3145.0638280843573 seconds
# Signal 3 name: aVR
# Signal 3 duration: 3145.0638280843573 seconds
# Signal 4 name: ABP
# Signal 4 duration: 3145.0638280843573 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 3145.0638280843573 seconds
# Signal 6 name: Resp
# Signal 6 duration: 3145.0638280843573 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0006 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 1229.3409100004003 seconds
# Signal 2 name: V
# Signal 2 duration: 1229.3409100004003 seconds
# Signal 3 name: aVR
# Signal 3 duration: 1229.3409100004003 seconds
# Signal 4 name: ABP
# Signal 4 duration: 1229.3409100004003 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 1229.3409100004003 seconds
# Signal 6 name: Resp
# Signal 6 duration: 1229.3409100004003 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0007 ---
# Number of signals: 6
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: aVR
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: ABP
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 5.122253791668334 seconds
# Signal 6 name: Resp
# Signal 6 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0008 ---
# Number of signals: 6
# Signal 1 name: III
# Signal 1 duration: 10.244507583336668 seconds
# Signal 2 name: V
# Signal 2 duration: 10.244507583336668 seconds
# Signal 3 name: II
# Signal 3 duration: 10.244507583336668 seconds
# Signal 4 name: ABP
# Signal 4 duration: 10.244507583336668 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 10.244507583336668 seconds
# Signal 6 name: Resp
# Signal 6 duration: 10.244507583336668 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0009 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 12231.942054503983 seconds
# Signal 2 name: V
# Signal 2 duration: 12231.942054503983 seconds
# Signal 3 name: aVR
# Signal 3 duration: 12231.942054503983 seconds
# Signal 4 name: ABP
# Signal 4 duration: 12231.942054503983 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 12231.942054503983 seconds
# Signal 6 name: Resp
# Signal 6 duration: 12231.942054503983 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0010 ---
# Number of signals: 1
# Signal 1 name: Pleth
# Signal 1 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0011 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 64222.81803993758 seconds
# Signal 2 name: V
# Signal 2 duration: 64222.81803993758 seconds
# Signal 3 name: aVR
# Signal 3 duration: 64222.81803993758 seconds
# Signal 4 name: ABP
# Signal 4 duration: 64222.81803993758 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 64222.81803993758 seconds
# Signal 6 name: Resp
# Signal 6 duration: 64222.81803993758 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0012 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 87.07831445836169 seconds
# Signal 2 name: V
# Signal 2 duration: 87.07831445836169 seconds
# Signal 3 name: aVR
# Signal 3 duration: 87.07831445836169 seconds
# Signal 4 name: ABP
# Signal 4 duration: 87.07831445836169 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 87.07831445836169 seconds
# Signal 6 name: Resp
# Signal 6 duration: 87.07831445836169 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0013 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 7104.56600904398 seconds
# Signal 2 name: V
# Signal 2 duration: 7104.56600904398 seconds
# Signal 3 name: aVR
# Signal 3 duration: 7104.56600904398 seconds
# Signal 4 name: ABP
# Signal 4 duration: 7104.56600904398 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 7104.56600904398 seconds
# Signal 6 name: Resp
# Signal 6 duration: 7104.56600904398 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0014 ---
# Number of signals: 6
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: aVR
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: ABP
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 5.122253791668334 seconds
# Signal 6 name: Resp
# Signal 6 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0015 ---
# Number of signals: 6
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: II
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: ABP
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 5.122253791668334 seconds
# Signal 6 name: Resp
# Signal 6 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0016 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 49573.17219576614 seconds
# Signal 2 name: V
# Signal 2 duration: 49573.17219576614 seconds
# Signal 3 name: aVR
# Signal 3 duration: 49573.17219576614 seconds
# Signal 4 name: ABP
# Signal 4 duration: 49573.17219576614 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 49573.17219576614 seconds
# Signal 6 name: Resp
# Signal 6 duration: 49573.17219576614 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0017 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 51.22253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 51.22253791668334 seconds
# Signal 3 name: aVR
# Signal 3 duration: 51.22253791668334 seconds
# Signal 4 name: ABP
# Signal 4 duration: 51.22253791668334 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 51.22253791668334 seconds
# Signal 6 name: Resp
# Signal 6 duration: 51.22253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0018 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 11007.723398295251 seconds
# Signal 2 name: V
# Signal 2 duration: 11007.723398295251 seconds
# Signal 3 name: aVR
# Signal 3 duration: 11007.723398295251 seconds
# Signal 4 name: ABP
# Signal 4 duration: 11007.723398295251 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 11007.723398295251 seconds
# Signal 6 name: Resp
# Signal 6 duration: 11007.723398295251 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0019 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 81367.0014806515 seconds
# Signal 2 name: V
# Signal 2 duration: 81367.0014806515 seconds
# Signal 3 name: aVR
# Signal 3 duration: 81367.0014806515 seconds
# Signal 4 name: ABP
# Signal 4 duration: 81367.0014806515 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 81367.0014806515 seconds
# Signal 6 name: Resp
# Signal 6 duration: 81367.0014806515 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0020 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 138.30085237504503 seconds
# Signal 2 name: V
# Signal 2 duration: 138.30085237504503 seconds
# Signal 3 name: aVR
# Signal 3 duration: 138.30085237504503 seconds
# Signal 4 name: ABP
# Signal 4 duration: 138.30085237504503 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 138.30085237504503 seconds
# Signal 6 name: Resp
# Signal 6 duration: 138.30085237504503 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0021 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 92.20056825003002 seconds
# Signal 2 name: V
# Signal 2 duration: 92.20056825003002 seconds
# Signal 3 name: aVR
# Signal 3 duration: 92.20056825003002 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 92.20056825003002 seconds
# Signal 5 name: Resp
# Signal 5 duration: 92.20056825003002 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0022 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 517.3476329585018 seconds
# Signal 2 name: V
# Signal 2 duration: 517.3476329585018 seconds
# Signal 3 name: aVR
# Signal 3 duration: 517.3476329585018 seconds
# Signal 4 name: ABP
# Signal 4 duration: 517.3476329585018 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 517.3476329585018 seconds
# Signal 6 name: Resp
# Signal 6 duration: 517.3476329585018 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0023 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 978.3504742086518 seconds
# Signal 2 name: V
# Signal 2 duration: 978.3504742086518 seconds
# Signal 3 name: aVR
# Signal 3 duration: 978.3504742086518 seconds
# Signal 4 name: ABP
# Signal 4 duration: 978.3504742086518 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 978.3504742086518 seconds
# Signal 6 name: Resp
# Signal 6 duration: 978.3504742086518 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0024 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 31337.94869742687 seconds
# Signal 2 name: V
# Signal 2 duration: 31337.94869742687 seconds
# Signal 3 name: aVR
# Signal 3 duration: 31337.94869742687 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 31337.94869742687 seconds
# Signal 5 name: Resp
# Signal 5 duration: 31337.94869742687 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83404654_0025 ---
# Number of signals: 1
# Signal 1 name: Pleth
# Signal 1 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# Total number of subsegments: 26
# Total number of subsegments with ABP and Pleth: 11
# Minimum and Maximum durations for ABP: 138.30085237504503 seconds, 81367.0014806515 seconds
# Minimum and Maximum durations for Pleth: 138.30085237504503 seconds, 81367.0014806515 seconds
# --- Segment Header Information for 83268087 ---
# Record name and segment number: 83268087
# Number of signals: 7
# Total duration: 493713.5539637441 seconds
# Sampling frequency: 62.4725 Hz
# Counter frequency: 999.56 Hz
# Number of samples per signal: 30843520
# Start time of the recording: 00:50:02.909000
# Start date of the recording: 2169-10-25
# Meta data: ['wfdb 10.7', 'subject_id 10100546', 'hadm_id 28954700']
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0000 ---
# Number of signals: 7
# Signal 1 name: I
# Signal 1 duration: 0.0 seconds
# Signal 2 name: II
# Signal 2 duration: 0.0 seconds
# Signal 3 name: III
# Signal 3 duration: 0.0 seconds
# Signal 4 name: V
# Signal 4 duration: 0.0 seconds
# Signal 5 name: aVR
# Signal 5 duration: 0.0 seconds
# Signal 6 name: Pleth
# Signal 6 duration: 0.0 seconds
# Signal 7 name: Resp
# Signal 7 duration: 0.0 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0001 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 1306.1747168754252 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 1306.1747168754252 seconds
# Signal 3 name: Resp
# Signal 3 duration: 1306.1747168754252 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0002 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 2.0489015166673337 seconds
# Signal 2 name: V
# Signal 2 duration: 2.0489015166673337 seconds
# Signal 3 name: aVR
# Signal 3 duration: 2.0489015166673337 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 2.0489015166673337 seconds
# Signal 5 name: Resp
# Signal 5 duration: 2.0489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0003 ---
# Number of signals: 4
# Signal 1 name: V
# Signal 1 duration: 3.0733522750010005 seconds
# Signal 2 name: aVR
# Signal 2 duration: 3.0733522750010005 seconds
# Signal 3 name: Pleth
# Signal 3 duration: 3.0733522750010005 seconds
# Signal 4 name: Resp
# Signal 4 duration: 3.0733522750010005 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0004 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: aVR
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: Resp
# Signal 5 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0005 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 8.451718756252752 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 8.451718756252752 seconds
# Signal 3 name: Resp
# Signal 3 duration: 8.451718756252752 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0006 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 1.792788827083917 seconds
# Signal 2 name: Resp
# Signal 2 duration: 1.792788827083917 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0007 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 2.0489015166673337 seconds
# Signal 2 name: V
# Signal 2 duration: 2.0489015166673337 seconds
# Signal 3 name: aVR
# Signal 3 duration: 2.0489015166673337 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 2.0489015166673337 seconds
# Signal 5 name: Resp
# Signal 5 duration: 2.0489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0008 ---
# Number of signals: 4
# Signal 1 name: V
# Signal 1 duration: 3.0733522750010005 seconds
# Signal 2 name: aVR
# Signal 2 duration: 3.0733522750010005 seconds
# Signal 3 name: Pleth
# Signal 3 duration: 3.0733522750010005 seconds
# Signal 4 name: Resp
# Signal 4 duration: 3.0733522750010005 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0009 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 15.366761375005003 seconds
# Signal 2 name: V
# Signal 2 duration: 15.366761375005003 seconds
# Signal 3 name: aVR
# Signal 3 duration: 15.366761375005003 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 15.366761375005003 seconds
# Signal 5 name: Resp
# Signal 5 duration: 15.366761375005003 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0010 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 9.476169514586418 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 9.476169514586418 seconds
# Signal 3 name: Resp
# Signal 3 duration: 9.476169514586418 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0011 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 0.7683380687502501 seconds
# Signal 2 name: Resp
# Signal 2 duration: 0.7683380687502501 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0012 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 3.0733522750010005 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 3.0733522750010005 seconds
# Signal 3 name: Resp
# Signal 3 duration: 3.0733522750010005 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0013 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 2.0489015166673337 seconds
# Signal 2 name: Resp
# Signal 2 duration: 2.0489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0014 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 0.2561126895834167 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 0.2561126895834167 seconds
# Signal 3 name: Resp
# Signal 3 duration: 0.2561126895834167 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0015 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 4.866141102084917 seconds
# Signal 2 name: Resp
# Signal 2 duration: 4.866141102084917 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0016 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 102.44507583336669 seconds
# Signal 2 name: V
# Signal 2 duration: 102.44507583336669 seconds
# Signal 3 name: aVR
# Signal 3 duration: 102.44507583336669 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 102.44507583336669 seconds
# Signal 5 name: Resp
# Signal 5 duration: 102.44507583336669 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0017 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 10.500620272920086 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 10.500620272920086 seconds
# Signal 3 name: Resp
# Signal 3 duration: 10.500620272920086 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0018 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 4.866141102084917 seconds
# Signal 2 name: Resp
# Signal 2 duration: 4.866141102084917 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0019 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 56.34479170835168 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 56.34479170835168 seconds
# Signal 3 name: Resp
# Signal 3 duration: 56.34479170835168 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0020 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 15445.644083396695 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 15445.644083396695 seconds
# Signal 3 name: Resp
# Signal 3 duration: 15445.644083396695 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0021 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 3.0733522750010005 seconds
# Signal 2 name: Resp
# Signal 2 duration: 3.0733522750010005 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0022 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 1.2805634479170835 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 1.2805634479170835 seconds
# Signal 3 name: Resp
# Signal 3 duration: 1.2805634479170835 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0023 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 3.841690343751251 seconds
# Signal 2 name: Resp
# Signal 2 duration: 3.841690343751251 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0024 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 271.4794509584217 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 271.4794509584217 seconds
# Signal 3 name: Resp
# Signal 3 duration: 271.4794509584217 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0025 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 1.0244507583336668 seconds
# Signal 2 name: V
# Signal 2 duration: 1.0244507583336668 seconds
# Signal 3 name: aVR
# Signal 3 duration: 1.0244507583336668 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 1.0244507583336668 seconds
# Signal 5 name: Resp
# Signal 5 duration: 1.0244507583336668 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0026 ---
# Number of signals: 4
# Signal 1 name: V
# Signal 1 duration: 4.097803033334667 seconds
# Signal 2 name: aVR
# Signal 2 duration: 4.097803033334667 seconds
# Signal 3 name: Pleth
# Signal 3 duration: 4.097803033334667 seconds
# Signal 4 name: Resp
# Signal 4 duration: 4.097803033334667 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0027 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 35.85577654167834 seconds
# Signal 2 name: V
# Signal 2 duration: 35.85577654167834 seconds
# Signal 3 name: aVR
# Signal 3 duration: 35.85577654167834 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 35.85577654167834 seconds
# Signal 5 name: Resp
# Signal 5 duration: 35.85577654167834 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0028 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 8.451718756252752 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 8.451718756252752 seconds
# Signal 3 name: Resp
# Signal 3 duration: 8.451718756252752 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0029 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 1.792788827083917 seconds
# Signal 2 name: Resp
# Signal 2 duration: 1.792788827083917 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0030 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 2.0489015166673337 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 2.0489015166673337 seconds
# Signal 3 name: Resp
# Signal 3 duration: 2.0489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0031 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 3.0733522750010005 seconds
# Signal 2 name: Resp
# Signal 2 duration: 3.0733522750010005 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0032 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 19310.896794589622 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 19310.896794589622 seconds
# Signal 3 name: Resp
# Signal 3 duration: 19310.896794589622 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0033 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: aVR
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: Resp
# Signal 5 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0034 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 97.32282204169836 seconds
# Signal 2 name: V
# Signal 2 duration: 97.32282204169836 seconds
# Signal 3 name: aVR
# Signal 3 duration: 97.32282204169836 seconds
# Signal 4 name: Resp
# Signal 4 duration: 97.32282204169836 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0035 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 6.402817239585418 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 6.402817239585418 seconds
# Signal 3 name: Resp
# Signal 3 duration: 6.402817239585418 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0036 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 3.841690343751251 seconds
# Signal 2 name: Resp
# Signal 2 duration: 3.841690343751251 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0037 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 978.3504742086518 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 978.3504742086518 seconds
# Signal 3 name: Resp
# Signal 3 duration: 978.3504742086518 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0038 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 7191.644323502342 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 7191.644323502342 seconds
# Signal 3 name: Resp
# Signal 3 duration: 7191.644323502342 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0039 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 35.85577654167834 seconds
# Signal 2 name: V
# Signal 2 duration: 35.85577654167834 seconds
# Signal 3 name: aVR
# Signal 3 duration: 35.85577654167834 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 35.85577654167834 seconds
# Signal 5 name: Resp
# Signal 5 duration: 35.85577654167834 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0040 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 10.500620272920086 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 10.500620272920086 seconds
# Signal 3 name: Resp
# Signal 3 duration: 10.500620272920086 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0041 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 4.866141102084917 seconds
# Signal 2 name: Resp
# Signal 2 duration: 4.866141102084917 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0042 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 1828.6446036255954 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 1828.6446036255954 seconds
# Signal 3 name: Resp
# Signal 3 duration: 1828.6446036255954 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0043 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 3.0733522750010005 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 3.0733522750010005 seconds
# Signal 3 name: Resp
# Signal 3 duration: 3.0733522750010005 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0044 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 2.0489015166673337 seconds
# Signal 2 name: Resp
# Signal 2 duration: 2.0489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0045 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 4230.9816319180445 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 4230.9816319180445 seconds
# Signal 3 name: Resp
# Signal 3 duration: 4230.9816319180445 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0046 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 9701.548681419825 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 9701.548681419825 seconds
# Signal 3 name: Resp
# Signal 3 duration: 9701.548681419825 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0047 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 1362.519508583777 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 1362.519508583777 seconds
# Signal 3 name: Resp
# Signal 3 duration: 1362.519508583777 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0048 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 3.0733522750010005 seconds
# Signal 2 name: V
# Signal 2 duration: 3.0733522750010005 seconds
# Signal 3 name: II
# Signal 3 duration: 3.0733522750010005 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 3.0733522750010005 seconds
# Signal 5 name: Resp
# Signal 5 duration: 3.0733522750010005 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0049 ---
# Number of signals: 4
# Signal 1 name: V
# Signal 1 duration: 2.0489015166673337 seconds
# Signal 2 name: II
# Signal 2 duration: 2.0489015166673337 seconds
# Signal 3 name: Pleth
# Signal 3 duration: 2.0489015166673337 seconds
# Signal 4 name: Resp
# Signal 4 duration: 2.0489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0050 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 15.366761375005003 seconds
# Signal 2 name: V
# Signal 2 duration: 15.366761375005003 seconds
# Signal 3 name: II
# Signal 3 duration: 15.366761375005003 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 15.366761375005003 seconds
# Signal 5 name: Resp
# Signal 5 duration: 15.366761375005003 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0051 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 10.500620272920086 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 10.500620272920086 seconds
# Signal 3 name: Resp
# Signal 3 duration: 10.500620272920086 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0052 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 4.866141102084917 seconds
# Signal 2 name: Resp
# Signal 2 duration: 4.866141102084917 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0053 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 7058.465724918965 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 7058.465724918965 seconds
# Signal 3 name: Resp
# Signal 3 duration: 7058.465724918965 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0054 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 1.0244507583336668 seconds
# Signal 2 name: V
# Signal 2 duration: 1.0244507583336668 seconds
# Signal 3 name: II
# Signal 3 duration: 1.0244507583336668 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 1.0244507583336668 seconds
# Signal 5 name: Resp
# Signal 5 duration: 1.0244507583336668 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0055 ---
# Number of signals: 4
# Signal 1 name: V
# Signal 1 duration: 4.097803033334667 seconds
# Signal 2 name: II
# Signal 2 duration: 4.097803033334667 seconds
# Signal 3 name: Pleth
# Signal 3 duration: 4.097803033334667 seconds
# Signal 4 name: Resp
# Signal 4 duration: 4.097803033334667 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0056 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 87.07831445836169 seconds
# Signal 2 name: V
# Signal 2 duration: 87.07831445836169 seconds
# Signal 3 name: II
# Signal 3 duration: 87.07831445836169 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 87.07831445836169 seconds
# Signal 5 name: Resp
# Signal 5 duration: 87.07831445836169 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0057 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 10.500620272920086 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 10.500620272920086 seconds
# Signal 3 name: Resp
# Signal 3 duration: 10.500620272920086 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0058 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 4.866141102084917 seconds
# Signal 2 name: Resp
# Signal 2 duration: 4.866141102084917 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0059 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 640.2817239585418 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 640.2817239585418 seconds
# Signal 3 name: Resp
# Signal 3 duration: 640.2817239585418 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0060 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: Resp
# Signal 3 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0061 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 15.366761375005003 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 15.366761375005003 seconds
# Signal 3 name: Resp
# Signal 3 duration: 15.366761375005003 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0062 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: Resp
# Signal 3 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0063 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 25.61126895834167 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 25.61126895834167 seconds
# Signal 3 name: Resp
# Signal 3 duration: 25.61126895834167 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0064 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 20.489015166673337 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 20.489015166673337 seconds
# Signal 3 name: Resp
# Signal 3 duration: 20.489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0065 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 20.489015166673337 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 20.489015166673337 seconds
# Signal 3 name: Resp
# Signal 3 duration: 20.489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0066 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 25.61126895834167 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 25.61126895834167 seconds
# Signal 3 name: Resp
# Signal 3 duration: 25.61126895834167 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0067 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 15.366761375005003 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 15.366761375005003 seconds
# Signal 3 name: Resp
# Signal 3 duration: 15.366761375005003 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0068 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 10.244507583336668 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 10.244507583336668 seconds
# Signal 3 name: Resp
# Signal 3 duration: 10.244507583336668 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0069 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: Resp
# Signal 3 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0070 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 13384.449157629359 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 13384.449157629359 seconds
# Signal 3 name: Resp
# Signal 3 duration: 13384.449157629359 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0071 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 12244.49157629357 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 12244.49157629357 seconds
# Signal 3 name: Resp
# Signal 3 duration: 12244.49157629357 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0072 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 2.817239585417584 seconds
# Signal 2 name: Resp
# Signal 2 duration: 2.817239585417584 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0073 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 20.489015166673337 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 20.489015166673337 seconds
# Signal 3 name: Resp
# Signal 3 duration: 20.489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0074 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: II
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: Resp
# Signal 5 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0075 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 6.402817239585418 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 6.402817239585418 seconds
# Signal 3 name: Resp
# Signal 3 duration: 6.402817239585418 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0076 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 3.841690343751251 seconds
# Signal 2 name: Resp
# Signal 2 duration: 3.841690343751251 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0077 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 343.1910040417784 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 343.1910040417784 seconds
# Signal 3 name: Resp
# Signal 3 duration: 343.1910040417784 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0078 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 3.0733522750010005 seconds
# Signal 2 name: V
# Signal 2 duration: 3.0733522750010005 seconds
# Signal 3 name: II
# Signal 3 duration: 3.0733522750010005 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 3.0733522750010005 seconds
# Signal 5 name: Resp
# Signal 5 duration: 3.0733522750010005 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0079 ---
# Number of signals: 4
# Signal 1 name: V
# Signal 1 duration: 2.0489015166673337 seconds
# Signal 2 name: II
# Signal 2 duration: 2.0489015166673337 seconds
# Signal 3 name: Pleth
# Signal 3 duration: 2.0489015166673337 seconds
# Signal 4 name: Resp
# Signal 4 duration: 2.0489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0080 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: II
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: Resp
# Signal 5 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0081 ---
# Number of signals: 3
# Signal 1 name: III
# Signal 1 duration: 8.451718756252752 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 8.451718756252752 seconds
# Signal 3 name: Resp
# Signal 3 duration: 8.451718756252752 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0082 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 1.792788827083917 seconds
# Signal 2 name: Resp
# Signal 2 duration: 1.792788827083917 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0083 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 3.0733522750010005 seconds
# Signal 2 name: V
# Signal 2 duration: 3.0733522750010005 seconds
# Signal 3 name: II
# Signal 3 duration: 3.0733522750010005 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 3.0733522750010005 seconds
# Signal 5 name: Resp
# Signal 5 duration: 3.0733522750010005 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0084 ---
# Number of signals: 4
# Signal 1 name: V
# Signal 1 duration: 2.0489015166673337 seconds
# Signal 2 name: II
# Signal 2 duration: 2.0489015166673337 seconds
# Signal 3 name: Pleth
# Signal 3 duration: 2.0489015166673337 seconds
# Signal 4 name: Resp
# Signal 4 duration: 2.0489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83268087_0085 ---
# Number of signals: 5
# Signal 1 name: III
# Signal 1 duration: 81.95606066669335 seconds
# Signal 2 name: V
# Signal 2 duration: 81.95606066669335 seconds
# Signal 3 name: II
# Signal 3 duration: 81.95606066669335 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 81.95606066669335 seconds
# Signal 5 name: Resp
# Signal 5 duration: 81.95606066669335 seconds
# --------------------------------------------------
#
# ...
# Signal 3 name: Resp
# Signal 3 duration: 3.3294649645844174 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0045 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 261.23494337508504 seconds
# Signal 2 name: V
# Signal 2 duration: 261.23494337508504 seconds
# Signal 3 name: aVR
# Signal 3 duration: 261.23494337508504 seconds
# Signal 4 name: Resp
# Signal 4 duration: 261.23494337508504 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0046 ---
# Number of signals: 2
# Signal 1 name: II
# Signal 1 duration: 8.963944135419585 seconds
# Signal 2 name: Resp
# Signal 2 duration: 8.963944135419585 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0047 ---
# Number of signals: 1
# Signal 1 name: Resp
# Signal 1 duration: 1.2805634479170835 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0048 ---
# Number of signals: 2
# Signal 1 name: II
# Signal 1 duration: 37730.521429428954 seconds
# Signal 2 name: Resp
# Signal 2 duration: 37730.521429428954 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0049 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 3.841690343751251 seconds
# Signal 2 name: V
# Signal 2 duration: 3.841690343751251 seconds
# Signal 3 name: aVR
# Signal 3 duration: 3.841690343751251 seconds
# Signal 4 name: Resp
# Signal 4 duration: 3.841690343751251 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0050 ---
# Number of signals: 3
# Signal 1 name: V
# Signal 1 duration: 1.2805634479170835 seconds
# Signal 2 name: aVR
# Signal 2 duration: 1.2805634479170835 seconds
# Signal 3 name: Resp
# Signal 3 duration: 1.2805634479170835 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0051 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 660.7707391252152 seconds
# Signal 2 name: V
# Signal 2 duration: 660.7707391252152 seconds
# Signal 3 name: aVR
# Signal 3 duration: 660.7707391252152 seconds
# Signal 4 name: Resp
# Signal 4 duration: 660.7707391252152 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0052 ---
# Number of signals: 2
# Signal 1 name: II
# Signal 1 duration: 7.939493377085919 seconds
# Signal 2 name: Resp
# Signal 2 duration: 7.939493377085919 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0053 ---
# Number of signals: 1
# Signal 1 name: Resp
# Signal 1 duration: 2.3050142062507506 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0054 ---
# Number of signals: 2
# Signal 1 name: II
# Signal 1 duration: 7878.026331585898 seconds
# Signal 2 name: Resp
# Signal 2 duration: 7878.026331585898 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0055 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 0.7683380687502501 seconds
# Signal 2 name: V
# Signal 2 duration: 0.7683380687502501 seconds
# Signal 3 name: aVR
# Signal 3 duration: 0.7683380687502501 seconds
# Signal 4 name: Resp
# Signal 4 duration: 0.7683380687502501 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0056 ---
# Number of signals: 3
# Signal 1 name: V
# Signal 1 duration: 4.353915722918084 seconds
# Signal 2 name: aVR
# Signal 2 duration: 4.353915722918084 seconds
# Signal 3 name: Resp
# Signal 3 duration: 4.353915722918084 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 81362381_0057 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 56.34479170835168 seconds
# Signal 2 name: V
# Signal 2 duration: 56.34479170835168 seconds
# Signal 3 name: aVR
# Signal 3 duration: 56.34479170835168 seconds
# Signal 4 name: Resp
# Signal 4 duration: 56.34479170835168 seconds
# --------------------------------------------------
#
# Total number of subsegments: 58
# Total number of subsegments with ABP and Pleth: 0
# Minimum and Maximum durations for ABP: inf seconds, 0 seconds
# Minimum and Maximum durations for Pleth: inf seconds, 0 seconds
# --- Segment Header Information for 83958172 ---
# Record name and segment number: 83958172
# Number of signals: 9
# Total duration: 199255.6724958982 seconds
# Sampling frequency: 62.4725 Hz
# Counter frequency: 999.56 Hz
# Number of samples per signal: 12448000
# Start time of the recording: 10:47:24.515000
# Start date of the recording: 2187-06-15
# Meta data: ['wfdb 10.7', 'subject_id 19619764', 'hadm_id 27591774']
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0000 ---
# Number of signals: 9
# Signal 1 name: II
# Signal 1 duration: 0.0 seconds
# Signal 2 name: III
# Signal 2 duration: 0.0 seconds
# Signal 3 name: V
# Signal 3 duration: 0.0 seconds
# Signal 4 name: aVR
# Signal 4 duration: 0.0 seconds
# Signal 5 name: ABP
# Signal 5 duration: 0.0 seconds
# Signal 6 name: CVP
# Signal 6 duration: 0.0 seconds
# Signal 7 name: PAP
# Signal 7 duration: 0.0 seconds
# Signal 8 name: Pleth
# Signal 8 duration: 0.0 seconds
# Signal 9 name: Resp
# Signal 9 duration: 0.0 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0001 ---
# Number of signals: 8
# Signal 1 name: II
# Signal 1 duration: 7360.678698627396 seconds
# Signal 2 name: V
# Signal 2 duration: 7360.678698627396 seconds
# Signal 3 name: aVR
# Signal 3 duration: 7360.678698627396 seconds
# Signal 4 name: ABP
# Signal 4 duration: 7360.678698627396 seconds
# Signal 5 name: PAP
# Signal 5 duration: 7360.678698627396 seconds
# Signal 6 name: CVP
# Signal 6 duration: 7360.678698627396 seconds
# Signal 7 name: Pleth
# Signal 7 duration: 7360.678698627396 seconds
# Signal 8 name: Resp
# Signal 8 duration: 7360.678698627396 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0002 ---
# Number of signals: 8
# Signal 1 name: III
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: II
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: ABP
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: PAP
# Signal 5 duration: 5.122253791668334 seconds
# Signal 6 name: CVP
# Signal 6 duration: 5.122253791668334 seconds
# Signal 7 name: Pleth
# Signal 7 duration: 5.122253791668334 seconds
# Signal 8 name: Resp
# Signal 8 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0003 ---
# Number of signals: 8
# Signal 1 name: II
# Signal 1 duration: 1126.8958341670336 seconds
# Signal 2 name: V
# Signal 2 duration: 1126.8958341670336 seconds
# Signal 3 name: aVR
# Signal 3 duration: 1126.8958341670336 seconds
# Signal 4 name: ABP
# Signal 4 duration: 1126.8958341670336 seconds
# Signal 5 name: PAP
# Signal 5 duration: 1126.8958341670336 seconds
# Signal 6 name: CVP
# Signal 6 duration: 1126.8958341670336 seconds
# Signal 7 name: Pleth
# Signal 7 duration: 1126.8958341670336 seconds
# Signal 8 name: Resp
# Signal 8 duration: 1126.8958341670336 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0004 ---
# Number of signals: 8
# Signal 1 name: II
# Signal 1 duration: 60314.53839689463 seconds
# Signal 2 name: V
# Signal 2 duration: 60314.53839689463 seconds
# Signal 3 name: aVR
# Signal 3 duration: 60314.53839689463 seconds
# Signal 4 name: ABP
# Signal 4 duration: 60314.53839689463 seconds
# Signal 5 name: PAP
# Signal 5 duration: 60314.53839689463 seconds
# Signal 6 name: CVP
# Signal 6 duration: 60314.53839689463 seconds
# Signal 7 name: Pleth
# Signal 7 duration: 60314.53839689463 seconds
# Signal 8 name: Resp
# Signal 8 duration: 60314.53839689463 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0005 ---
# Number of signals: 7
# Signal 1 name: II
# Signal 1 duration: 5.122253791668334 seconds
# Signal 2 name: V
# Signal 2 duration: 5.122253791668334 seconds
# Signal 3 name: aVR
# Signal 3 duration: 5.122253791668334 seconds
# Signal 4 name: ABP
# Signal 4 duration: 5.122253791668334 seconds
# Signal 5 name: CVP
# Signal 5 duration: 5.122253791668334 seconds
# Signal 6 name: Pleth
# Signal 6 duration: 5.122253791668334 seconds
# Signal 7 name: Resp
# Signal 7 duration: 5.122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0006 ---
# Number of signals: 6
# Signal 1 name: II
# Signal 1 duration: 21329.064788506945 seconds
# Signal 2 name: V
# Signal 2 duration: 21329.064788506945 seconds
# Signal 3 name: aVR
# Signal 3 duration: 21329.064788506945 seconds
# Signal 4 name: ABP
# Signal 4 duration: 21329.064788506945 seconds
# Signal 5 name: Pleth
# Signal 5 duration: 21329.064788506945 seconds
# Signal 6 name: Resp
# Signal 6 duration: 21329.064788506945 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0007 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 10167.673776461643 seconds
# Signal 2 name: V
# Signal 2 duration: 10167.673776461643 seconds
# Signal 3 name: aVR
# Signal 3 duration: 10167.673776461643 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 10167.673776461643 seconds
# Signal 5 name: Resp
# Signal 5 duration: 10167.673776461643 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0008 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 102.44507583336669 seconds
# Signal 2 name: V
# Signal 2 duration: 102.44507583336669 seconds
# Signal 3 name: aVR
# Signal 3 duration: 102.44507583336669 seconds
# Signal 4 name: Resp
# Signal 4 duration: 102.44507583336669 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0009 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 66271.7195566049 seconds
# Signal 2 name: V
# Signal 2 duration: 66271.7195566049 seconds
# Signal 3 name: aVR
# Signal 3 duration: 66271.7195566049 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 66271.7195566049 seconds
# Signal 5 name: Resp
# Signal 5 duration: 66271.7195566049 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0010 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 476.3696026251551 seconds
# Signal 2 name: V
# Signal 2 duration: 476.3696026251551 seconds
# Signal 3 name: aVR
# Signal 3 duration: 476.3696026251551 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 476.3696026251551 seconds
# Signal 5 name: Resp
# Signal 5 duration: 476.3696026251551 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0011 ---
# Number of signals: 3
# Signal 1 name: II
# Signal 1 duration: 9.732282204169834 seconds
# Signal 2 name: Pleth
# Signal 2 duration: 9.732282204169834 seconds
# Signal 3 name: Resp
# Signal 3 duration: 9.732282204169834 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0012 ---
# Number of signals: 2
# Signal 1 name: Pleth
# Signal 1 duration: 0.5122253791668334 seconds
# Signal 2 name: Resp
# Signal 2 duration: 0.5122253791668334 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0013 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 1.2805634479170835 seconds
# Signal 2 name: V
# Signal 2 duration: 1.2805634479170835 seconds
# Signal 3 name: aVR
# Signal 3 duration: 1.2805634479170835 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 1.2805634479170835 seconds
# Signal 5 name: Resp
# Signal 5 duration: 1.2805634479170835 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0014 ---
# Number of signals: 4
# Signal 1 name: V
# Signal 1 duration: 3.841690343751251 seconds
# Signal 2 name: aVR
# Signal 2 duration: 3.841690343751251 seconds
# Signal 3 name: Pleth
# Signal 3 duration: 3.841690343751251 seconds
# Signal 4 name: Resp
# Signal 4 duration: 3.841690343751251 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0015 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 11340.669894753692 seconds
# Signal 2 name: V
# Signal 2 duration: 11340.669894753692 seconds
# Signal 3 name: aVR
# Signal 3 duration: 11340.669894753692 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 11340.669894753692 seconds
# Signal 5 name: Resp
# Signal 5 duration: 11340.669894753692 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0016 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 5439.833526751771 seconds
# Signal 2 name: V
# Signal 2 duration: 5439.833526751771 seconds
# Signal 3 name: aVR
# Signal 3 duration: 5439.833526751771 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 5439.833526751771 seconds
# Signal 5 name: Resp
# Signal 5 duration: 5439.833526751771 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0017 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 20.489015166673337 seconds
# Signal 2 name: V
# Signal 2 duration: 20.489015166673337 seconds
# Signal 3 name: aVR
# Signal 3 duration: 20.489015166673337 seconds
# Signal 4 name: Resp
# Signal 4 duration: 20.489015166673337 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0018 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 522.4698867501701 seconds
# Signal 2 name: V
# Signal 2 duration: 522.4698867501701 seconds
# Signal 3 name: aVR
# Signal 3 duration: 522.4698867501701 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 522.4698867501701 seconds
# Signal 5 name: Resp
# Signal 5 duration: 522.4698867501701 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0019 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 76.83380687502502 seconds
# Signal 2 name: V
# Signal 2 duration: 76.83380687502502 seconds
# Signal 3 name: aVR
# Signal 3 duration: 76.83380687502502 seconds
# Signal 4 name: Resp
# Signal 4 duration: 76.83380687502502 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0020 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 12365.120653087359 seconds
# Signal 2 name: V
# Signal 2 duration: 12365.120653087359 seconds
# Signal 3 name: aVR
# Signal 3 duration: 12365.120653087359 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 12365.120653087359 seconds
# Signal 5 name: Resp
# Signal 5 duration: 12365.120653087359 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0021 ---
# Number of signals: 4
# Signal 1 name: II
# Signal 1 duration: 1234.4631637920686 seconds
# Signal 2 name: V
# Signal 2 duration: 1234.4631637920686 seconds
# Signal 3 name: aVR
# Signal 3 duration: 1234.4631637920686 seconds
# Signal 4 name: Resp
# Signal 4 duration: 1234.4631637920686 seconds
# --------------------------------------------------
#
# --- Subsegment Signal Information for 83958172_0022 ---
# Number of signals: 5
# Signal 1 name: II
# Signal 1 duration: 389.29128816679344 seconds
# Signal 2 name: V
# Signal 2 duration: 389.29128816679344 seconds
# Signal 3 name: aVR
# Signal 3 duration: 389.29128816679344 seconds
# Signal 4 name: Pleth
# Signal 4 duration: 389.29128816679344 seconds
# Signal 5 name: Resp
# Signal 5 duration: 389.29128816679344 seconds
# --------------------------------------------------
#
# Total number of subsegments: 23
# Total number of subsegments with ABP and Pleth: 4
# Minimum and Maximum durations for ABP: 1126.8958341670336 seconds, 60314.53839689463 seconds
# Minimum and Maximum durations for Pleth: 1126.8958341670336 seconds, 60314.53839689463 seconds
# Number of patients with subsegments having both ABP and Pleth: 4
# Total number of patients that satisfied the condition: 4

# %%
all_subsegments_abp_pleth
# Out:
# ['E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0005.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0006.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0009.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0011.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0013.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0016.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0018.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0019.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0020.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0022.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p10020306\\83404654\\83404654_0023.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p16818396\\89225487\\89225487_0007.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p16818396\\89225487\\89225487_0008.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p16818396\\89225487\\89225487_0010.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p16818396\\89225487\\89225487_0011.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p16818396\\89225487\\89225487_0012.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p16818396\\89225487\\89225487_0013.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p17744715\\80497954\\80497954_0010.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p17744715\\80497954\\80497954_0012.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p17744715\\80497954\\80497954_0013.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p17744715\\80497954\\80497954_0016.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p17744715\\80497954\\80497954_0018.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p17744715\\80497954\\80497954_0020.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p17744715\\80497954\\80497954_0021.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p19619764\\83958172\\83958172_0001.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p19619764\\83958172\\83958172_0003.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p19619764\\83958172\\83958172_0004.dat',
#  'E:\\Research\\Project Tiny\\physionet.org\\files\\mimic4wdb\\0.1.0\\waves\\train\\p19619764\\83958172\\83958172_0006.dat']

# %% [markdown]
# #### We now create a dataframe with maximum duration of 3 minutes and each reading each column.

# %% [markdown]
# Since the sampling frequency was found out to be 62.47 in the meta data we round it and use it in calculating the samples per minute.

# %%
import pandas as pd
import wfdb
import os

# Initialize two separate lists to store ABP and Pleth data
abp_data = []
pleth_data = []

# Define the number of samples per minute assuming a sampling rate 
sampling_rate = 62   # sampling rate rounded to 62 as sampling frequency is 62.47
samples_per_minute = 60 * sampling_rate
max_samples = 3 * samples_per_minute  # 3 minutes of data

# Iterate through each subsegment that contains both ABP and Pleth signals
for subsegment_path in all_subsegments_abp_pleth:
    # Extract the combined unique id from the file path
    parts = subsegment_path.split(os.sep)
    patient_no = parts[-3]
    segment_no = parts[-2]
    subsegment_no = parts[-1].split('.')[0]
    combined_id = patient_no + '_' + subsegment_no
    
    # Read the signal data using the rdrecord function
    record = wfdb.rdrecord(subsegment_path[:-4])
    
    # Extract ABP and Pleth signals
    abp_signal = record.p_signal[:, record.sig_name.index('ABP')]
    pleth_signal = record.p_signal[:, record.sig_name.index('Pleth')]
    
    # Limit the signal to the first 3 minutes
    abp_signal = abp_signal[:max_samples]
    pleth_signal = pleth_signal[:max_samples]
    
    # Append the data to the respective lists
    abp_data.append([combined_id] + abp_signal.tolist())
    pleth_data.append([combined_id] + pleth_signal.tolist())

# Create DataFrames from the lists
abp_df = pd.DataFrame(abp_data)
pleth_df = pd.DataFrame(pleth_data)

# Rename the first column of abp_df and pleth_df to 'combined_unique_id'
abp_df.rename(columns={0: 'combined_unique_id'}, inplace=True)
pleth_df.rename(columns={0: 'combined_unique_id'}, inplace=True)

# Print the DataFrames
# print(abp_df)
# print(pleth_df)

# %%
abp_df.head()
# Out:
#         combined_unique_id        1        2        3        4        5  \
# 0  p10020306_83404654_0005      NaN      NaN      NaN      NaN      NaN
# 1  p10020306_83404654_0006  72.5000  72.4375  72.1875  72.2500  73.8750
# 2  p10020306_83404654_0009  80.3125  75.6250  70.9375  68.4375  68.9375
# 3  p10020306_83404654_0011      NaN      NaN      NaN      NaN      NaN
# 4  p10020306_83404654_0013  61.6250  61.1875  60.7500  60.2500  59.8125
#
#          6        7        8        9  ...    11151     11152     11153  \
# 0      NaN      NaN      NaN      NaN  ...   29.000   29.0000   29.0000
# 1  78.3125  85.0625  91.6875  96.1875  ...  109.375  107.5625  104.8125
# 2  69.7500  69.0000  67.6875  67.2500  ...   57.500   56.9375   56.3125
# 3      NaN      NaN      NaN      NaN  ...   74.125   73.6875   72.9375
# 4  59.3750  58.8750  58.5000  58.1875  ...   58.875   58.6250   58.4375
#
#       11154    11155    11156    11157    11158    11159    11160
# 0   29.0000  29.0625  29.0000  28.8125  28.6250  28.5625  28.6250
# 1  101.3750  97.5625  94.3125  92.8750  92.9375  93.0625  92.4375
# 2   55.7500  55.1250  54.7500  54.5000  54.2500  53.8750  53.3750
# 3   71.8125  71.6250  71.6250  70.7500  70.3125  70.2500  69.4375
# 4   58.1875  58.0625  57.9375  57.7500  57.8125  58.5000  61.6875
#
# [5 rows x 11161 columns]

# %%
abp_df
# Out:
#          combined_unique_id         1         2         3         4         5  \
# 0   p10020306_83404654_0005       NaN       NaN       NaN       NaN       NaN
# 1   p10020306_83404654_0006   72.5000   72.4375   72.1875   72.2500   73.8750
# 2   p10020306_83404654_0009   80.3125   75.6250   70.9375   68.4375   68.9375
# 3   p10020306_83404654_0011       NaN       NaN       NaN       NaN       NaN
# 4   p10020306_83404654_0013   61.6250   61.1875   60.7500   60.2500   59.8125
# 5   p10020306_83404654_0016   65.6250   65.1875   64.7500   64.2500   63.8750
# 6   p10020306_83404654_0018   57.4375   57.0625   56.6875   56.4375   56.2500
# 7   p10020306_83404654_0019       NaN       NaN       NaN       NaN       NaN
# 8   p10020306_83404654_0020    0.0000    0.0000    0.0000    0.0000    0.0000
# 9   p10020306_83404654_0022       NaN       NaN       NaN       NaN       NaN
# 10  p10020306_83404654_0023  124.2500  124.2500  124.1875  124.1250  124.1250
# 11  p16818396_89225487_0007       NaN       NaN       NaN       NaN       NaN
# 12  p16818396_89225487_0008   69.3125   68.5625   67.5625   66.6250   66.0625
# 13  p16818396_89225487_0010   61.5625   60.1250   60.3125   61.5000   63.3750
# 14  p16818396_89225487_0011   59.0625   58.7500   58.4375   58.2500   58.0625
# 15  p16818396_89225487_0012   63.6875   61.8125   61.0000   62.4375   61.7500
# 16  p16818396_89225487_0013   53.3125   52.6250   51.8750   51.1875   51.0625
# 17  p17744715_80497954_0010   68.6250   73.9375   66.3750   50.9375   46.4375
# 18  p17744715_80497954_0012    0.8750    0.8750    0.8750    0.8750    0.9375
# 19  p17744715_80497954_0013   60.5625   57.6875   54.8750   52.2500   50.1875
# 20  p17744715_80497954_0016       NaN       NaN       NaN       NaN       NaN
# 21  p17744715_80497954_0018       NaN       NaN       NaN       NaN       NaN
# 22  p17744715_80497954_0020       NaN       NaN       NaN       NaN       NaN
# 23  p17744715_80497954_0021  101.1875   93.5000   86.0000   79.7500   73.6875
# 24  p19619764_83958172_0001       NaN       NaN       NaN       NaN       NaN
# 25  p19619764_83958172_0003   70.2500   70.6250   71.6875   72.8125   73.7500
# 26  p19619764_83958172_0004  110.1875  109.0000  107.0000  103.9375   99.7500
# 27  p19619764_83958172_0006   53.5625   52.6875   51.7500   50.9375   50.5625
#
#            6         7         8         9  ...     11151     11152     11153  \
# 0        NaN       NaN       NaN       NaN  ...   29.0000   29.0000   29.0000
# 1    78.3125   85.0625   91.6875   96.1875  ...  109.3750  107.5625  104.8125
# 2    69.7500   69.0000   67.6875   67.2500  ...   57.5000   56.9375   56.3125
# 3        NaN       NaN       NaN       NaN  ...   74.1250   73.6875   72.9375
# 4    59.3750   58.8750   58.5000   58.1875  ...   58.8750   58.6250   58.4375
# 5    63.4375   63.1875   63.1250   63.3125  ...   71.3750   70.8750   70.5000
# 6    55.9375   55.4375   55.0000   54.5000  ...   71.8750   71.3125   68.1250
# 7        NaN       NaN       NaN       NaN  ...   61.3750   60.8750   60.5625
# 8     0.0000    0.0000    0.0000    0.0000  ...       NaN       NaN       NaN
# 9        NaN       NaN       NaN       NaN  ...   96.1250   95.7500   95.5000
# 10  124.1875  124.2500  124.5000  124.9375  ...  108.0625  107.8750  107.6875
# 11       NaN       NaN       NaN       NaN  ...   73.6875   73.0000   71.9375
# 12   65.8750   66.5625   70.5000   82.0625  ...   67.5000   67.1875   67.0000
# 13   65.6250   67.8125   69.3750   70.0625  ...   65.0000   60.7500   58.3125
# 14   57.8750   57.6875   57.3125   56.9375  ...   51.5000   51.2500   50.8750
# 15   61.2500   61.6250   61.7500   61.6875  ...   54.0625   28.4375   48.0625
# 16   54.5000   66.9375   87.1250  109.2500  ...   97.0000   89.3750   84.1250
# 17   55.1250   76.8125  105.1875  113.1250  ...   10.5000  -42.3125  -17.0625
# 18    0.9375    0.9375    0.9375    0.9375  ...   65.1250   67.5625   68.1875
# 19   49.0625   50.5625   57.4375   70.0000  ...   75.7500   89.5625   99.7500
# 20       NaN       NaN       NaN       NaN  ...   60.8750   60.0000   58.6250
# 21       NaN       NaN       NaN       NaN  ...   98.0000   95.5000   89.7500
# 22       NaN       NaN       NaN       NaN  ...   53.1250   56.8125   59.1250
# 23   67.0000   61.1250   56.5000   53.4375  ...  174.5000  171.0000  163.5000
# 24       NaN       NaN       NaN       NaN  ...   87.2500   86.9375   86.6250
# 25   74.1875   74.0625   73.5000   72.6875  ...   64.1875   64.1875   64.2500
# 26   95.5000   92.3750   90.3125   89.1875  ...   92.9375   91.0625   88.6250
# 27   52.1250   58.2500   70.6250   84.4375  ...   87.6875  100.3125  105.7500
#
#        11154     11155     11156     11157     11158     11159     11160
# 0    29.0000   29.0625   29.0000   28.8125   28.6250   28.5625   28.6250
# 1   101.3750   97.5625   94.3125   92.8750   92.9375   93.0625   92.4375
# 2    55.7500   55.1250   54.7500   54.5000   54.2500   53.8750   53.3750
# 3    71.8125   71.6250   71.6250   70.7500   70.3125   70.2500   69.4375
# 4    58.1875   58.0625   57.9375   57.7500   57.8125   58.5000   61.6875
# 5    70.0625   69.5625   69.0625   68.5625   68.0625   67.5625   67.1250
# 6    63.6250   59.0000   56.4375   56.3125   56.6250   56.6250   56.5000
# 7    60.2500   60.0000   59.6250   59.0000   58.5625   58.2500   57.9375
# 8        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9    96.0000   97.4375   99.5000  101.5625  103.3750  104.6250  104.8750
# 10  107.5625  107.4375  107.2500  107.1250  107.1250  107.5000  107.4375
# 11   70.6250   69.3750   68.1875   67.0000   65.7500   64.7500   63.7500
# 12   66.8750   66.6250   66.1875   65.6875   64.9375   64.0625   63.2500
# 13   58.3125   59.8125   62.1250   65.1250   68.3750   71.4375   73.6875
# 14   50.3750   49.9375   50.4375   57.1250   77.3750  105.8750  130.5625
# 15   87.6250   72.1875   59.9375   57.3750   53.6250   50.6250   55.8125
# 16   82.6250   83.9375   86.6875   89.0000   89.9375   89.3125   87.3750
# 17   43.8750   51.2500   41.4375   91.5625  149.0000  162.6875  192.1250
# 18   66.5000   65.1250   63.9375   61.2500   58.9375   58.0000   55.9375
# 19  103.5625  100.5625   92.3750   81.7500   70.7500   60.3750   51.1875
# 20   57.1875   55.5000   53.9375   53.0625   53.4375   57.3750   66.1250
# 21   82.5625   75.1250   68.0625   61.1875   54.8125   49.3750   45.2500
# 22   60.8750   63.4375   65.2500   65.0625   64.7500   65.1250   63.5000
# 23  154.5000  145.9375  138.6250  132.1250  126.1250  120.5000  115.6250
# 24   86.4375   88.5000   93.8750  101.4375  109.8750  117.7500  123.7500
# 25   65.6250   68.8750   73.1875   78.0000   82.8125   87.2500   89.6875
# 26   86.3125   83.3125   80.3750   78.6250   77.3750   76.8125   76.8125
# 27  105.6250  102.1250   98.1875   95.0000   91.1250   86.6250   81.3750
#
# [28 rows x 11161 columns]

# %%
pleth_df
# Out:
#          combined_unique_id         1         2         3         4         5  \
# 0   p10020306_83404654_0005  0.502930  0.502930  0.502930  0.500000  0.498535
# 1   p10020306_83404654_0006  0.558105  0.553955  0.549805  0.545654  0.541504
# 2   p10020306_83404654_0009  0.395752  0.404053  0.412354  0.428955  0.454102
# 3   p10020306_83404654_0011  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   p10020306_83404654_0013  0.440918  0.427490  0.414062  0.400879  0.387451
# 5   p10020306_83404654_0016  0.520752  0.516602  0.512451  0.508301  0.500000
# 6   p10020306_83404654_0018  0.416748  0.427490  0.438232  0.443604  0.446289
# 7   p10020306_83404654_0019  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   p10020306_83404654_0020  0.280518  0.297852  0.317139  0.338379  0.359375
# 9   p10020306_83404654_0022  0.500000  0.500000  0.487305  0.479004  0.466553
# 10  p10020306_83404654_0023  0.648438  0.637207  0.620361  0.609131  0.597900
# 11  p16818396_89225487_0007  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  p16818396_89225487_0008  0.369141  0.363281  0.356934  0.349121  0.340088
# 13  p16818396_89225487_0010  0.256592  0.261963  0.294678  0.369873  0.481201
# 14  p16818396_89225487_0011  0.404785  0.401123  0.393066  0.382568  0.372070
# 15  p16818396_89225487_0012  0.426758  0.413086  0.407227  0.406006  0.406250
# 16  p16818396_89225487_0013  0.338379  0.336426  0.333984  0.331787  0.330078
# 17  p17744715_80497954_0010  0.500000  0.500000  0.500000  0.500000  0.500000
# 18  p17744715_80497954_0012  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  p17744715_80497954_0013  0.623779  0.589111  0.553955  0.515869  0.475830
# 20  p17744715_80497954_0016  0.652832  0.603516  0.549561  0.493408  0.438721
# 21  p17744715_80497954_0018  0.534180  0.613037  0.675049  0.706787  0.704834
# 22  p17744715_80497954_0020  0.715332  0.680420  0.632568  0.584717  0.534180
# 23  p17744715_80497954_0021  0.414795  0.412354  0.408691  0.405029  0.402344
# 24  p19619764_83958172_0001  0.000000  0.000000  0.000000  0.000000  0.000000
# 25  p19619764_83958172_0003  0.416504  0.411621  0.412354  0.416260  0.425049
# 26  p19619764_83958172_0004  0.432861  0.427002  0.421387  0.417480  0.414551
# 27  p19619764_83958172_0006  0.345459  0.344238  0.346191  0.350098  0.354492
#
#            6         7         8         9  ...     11151     11152     11153  \
# 0   0.494141  0.489502  0.483643  0.474854  ...  0.583252  0.583252  0.583252
# 1   0.537354  0.533203  0.529053  0.524902  ...  0.541504  0.541504  0.541504
# 2   0.483154  0.508301  0.545654  0.587402  ...  0.757324  0.755127  0.751953
# 3   0.000000  0.000000  0.000000  0.000000  ...  0.624756  0.617676  0.614258
# 4   0.374023  0.360596  0.347168  0.336426  ...  0.621094  0.605469  0.595215
# 5   0.500000  0.491455  0.487305  0.483154  ...  0.625000  0.620605  0.616455
# 6   0.446289  0.440918  0.435547  0.427490  ...  0.496338  0.489014  0.478516
# 7   0.000000  0.000000  0.000000  0.000000  ...  0.491455  0.491455  0.491455
# 8   0.378662  0.395996  0.411377  0.424805  ...       NaN       NaN       NaN
# 9   0.454102  0.445801  0.437500  0.428955  ...  0.554443  0.548096  0.535156
# 10  0.581055  0.575439  0.564209  0.555908  ...  0.483887  0.467773  0.454346
# 11  0.000000  0.000000  0.000000  0.000000  ...  0.629639  0.592041  0.553467
# 12  0.331299  0.322021  0.313232  0.306641  ...  0.447266  0.447998  0.456787
# 13  0.598877  0.688477  0.731445  0.741943  ...  0.246338  0.241455  0.237061
# 14  0.361328  0.349121  0.337646  0.326904  ...  0.271973  0.264160  0.257812
# 15  0.403809  0.398193  0.389404  0.377441  ...  0.325684  0.329346  0.328369
# 16  0.328125  0.326416  0.324463  0.321777  ...  0.274902  0.274170  0.292969
# 17  0.500000  0.500000  0.500000  0.500000  ...  0.394043  0.402344  0.413574
# 18  0.000000  0.000000  0.000000  0.000000  ...  0.567871  0.557617  0.537109
# 19  0.438477  0.406250  0.381836  0.365967  ...  0.369873  0.372070  0.381348
# 20  0.389404  0.352295  0.322266  0.304688  ...  0.478271  0.438477  0.395752
# 21  0.675781  0.634033  0.584717  0.529053  ...  0.388428  0.393799  0.393799
# 22  0.479248  0.424561  0.373047  0.327148  ...  0.689209  0.680908  0.657959
# 23  0.402832  0.405518  0.409424  0.412842  ...  0.460205  0.456787  0.451172
# 24  0.000000  0.000000  0.000000  0.000000  ...  0.429443  0.417725  0.411621
# 25  0.439453  0.461426  0.492188  0.523438  ...  0.498779  0.493896  0.488281
# 26  0.413330  0.410645  0.407715  0.407715  ...  0.466309  0.460205  0.454834
# 27  0.357910  0.360840  0.363281  0.364258  ...  0.420654  0.412842  0.403320
#
#        11154     11155     11156     11157     11158     11159     11160
# 0   0.574951  0.574951  0.574951  0.566650  0.562256  0.558105  0.549805
# 1   0.541504  0.549805  0.553955  0.562256  0.574951  0.587402  0.604004
# 2   0.747803  0.742920  0.738525  0.999756  0.999756  0.999756  0.999756
# 3   0.606934  0.603271  0.592773  0.585693  0.574707  0.567627  0.557129
# 4   0.584961  0.574463  0.564209  0.559082  0.548828  0.533203  0.522949
# 5   0.612305  0.608154  0.608154  0.604004  0.608154  0.608154  0.608154
# 6   0.471436  0.464111  0.457031  0.449951  0.446289  0.439209  0.431885
# 7   0.491455  0.491455  0.500000  0.500000  0.512451  0.520752  0.524902
# 8        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9   0.522217  0.512695  0.503174  0.500000  0.493408  0.483887  0.477295
# 10  0.438232  0.427490  0.422119  0.419434  0.414307  0.414307  0.419434
# 11  0.515137  0.478271  0.443359  0.410156  0.383057  0.363281  0.351318
# 12  0.469238  0.480713  0.486572  0.486084  0.479980  0.469971  0.459717
# 13  0.238037  0.260010  0.316895  0.406738  0.502686  0.570068  0.609863
# 14  0.253418  0.251221  0.250977  0.250244  0.249023  0.247803  0.246582
# 15  0.320068  0.302979  0.278320  0.249023  0.221191  0.184814  0.145020
# 16  0.353027  0.453857  0.566162  0.651855  0.690674  0.696289  0.679199
# 17  0.427979  0.440430  0.447754  0.451416  0.451172  0.448242  0.443115
# 18  0.510010  0.479248  0.446777  0.416992  0.393799  0.372314  0.356934
# 19  0.395752  0.414551  0.434082  0.449951  0.460693  0.465576  0.466309
# 20  0.356689  0.324463  0.301270  0.290283  0.288574  0.294434  0.308350
# 21  0.388428  0.379639  0.369141  0.357910  0.347900  0.337158  0.333496
# 22  0.627930  0.596436  0.558350  0.516602  0.473389  0.433105  0.398193
# 23  0.443604  0.435059  0.426270  0.419922  0.412598  0.406250  0.401855
# 24  0.407227  0.404297  0.400635  0.396729  0.392822  0.389160  0.386475
# 25  0.483887  0.479980  0.476807  0.472168  0.466797  0.464600  0.463867
# 26  0.449219  0.441650  0.434326  0.429199  0.427002  0.424072  0.422119
# 27  0.393311  0.384033  0.375244  0.365479  0.355957  0.347168  0.339600
#
# [28 rows x 11161 columns]

# %%
# import matplotlib.pyplot as plt

# # Plot the Pleth and ABP signals for each patient
# for combined_id in abp_df['combined_unique_id']:
#     # Extract the signals for the current patient
#     abp_signal = abp_df[abp_df['combined_unique_id'] == combined_id].iloc[0, 1:].dropna().values
#     pleth_signal = pleth_df[pleth_df['combined_unique_id'] == combined_id].iloc[0, 1:].dropna().values
    
#     # Create a new figure
#     plt.figure(figsize=(12, 6))
    
#     # Plot ABP signal
#     plt.subplot(2, 1, 1)
#     plt.plot(abp_signal, label='ABP')
#     plt.title(f'ABP Signal for {combined_id}')
#     plt.xlabel('Sample')
#     plt.ylabel('ABP')
#     plt.legend()
    
#     # Plot Pleth signal
#     plt.subplot(2, 1, 2)
#     plt.plot(pleth_signal, label='Pleth', color='orange')
#     plt.title(f'Pleth Signal for {combined_id}')
#     plt.xlabel('Sample')
#     plt.ylabel('Pleth')
#     plt.legend()
    
#     # Show the plot
#     plt.tight_layout()
#     plt.show()
